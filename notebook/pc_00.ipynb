# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #f3d9ff, #f8cdda);
#     padding: 40px;
#     border-radius: 12px;
#     text-align: center;
# ">
#     <h1>Python Fundamentals</h1>
#     <h2>Session 00 - Introductions</h2>
#     <hr style="width: 60%; margin: 20px auto;">
#     <h3>Amirmasoud Mohammadian</h3>
#     <a href="https://github.com/AmirmasoudCS/Python-mini-course"
#        style="display: inline-block; margin-top: 25px; text-decoration:none; color:inherit;" onmouseover="this.style.opacity='0.85'" onmouseout="this.style.opacity='1'">
#         <img src="../GitHub_Lockup_Black.png"
#              style="width: 48px; height: auto; opacity: 0.75; vertical-align:middle; display:inline;">
#              <span style="color:#555; font-size:11px; margin-left:1px; vertical-align:middle"><b>AmirmasoudCS</b></span>
#     </a>
# </div>

# %% [markdown]
# <div>
#     <ol>
#         <b><li><a href="./pc_01.ipynb">Install Dependencies</a></li></b>
#             <ul>
#                 <li>Installing VS Code</li>
#                 <li>Installing Extentions</li>
#                 <li>Downloading Python</li>
#                 <li>Mirroring</li>
#                 <li>Documents</li>
#             </ul>
#         <b><li><a href="./pc_02.ipynb">Variables and Data Type</a></li></b>
#             <ul>
#                 <li>Variables</li>
#                 <li>Naming Rules</li>
#                 <li>Basic data types</li>
#                 <li>Type conversions</li>
#             </ul>
#         <b><li><a href="./pc_03.ipynb">Input and Output</a></li></b>
#             <ul>
#                 <li>print()</li>
#                 <li>input()</li>
#                 <li>Formatting output</li>
#             </ul>
#         <b><li><a href="./pc_04.ipynb">Operators</a></li></b>
#             <ul>
#                 <li>Arithmetic operators (+ - * / % **)</li>
#                 <li>Comparison operators (== != > < >= <=)</li>
#                 <li>Logical Operators (and , or , not)</li>
#             </ul>
#         <b><li><a href="./pc_05.ipynb">Conditional Statements</a></li></b>
#             <ul>
#                 <li>if</li>
#                 <li>elif</li>
#                 <li>else</li>
#             </ul>
#         <b><li><a href="./pc_06.ipynb">Loops</a></li></b>
#             <ul>
#                 <li>for loops</li>
#                 <li>while loops</li>
#                 <li>break</li>
#                 <li>continue</li>
#                 <li>range()</li>
#             </ul>
#         <b><li><a href="./pc_07.ipynb">Data Structures</a></li></b>
#             <ul>
#                 <li>Lists</li>
#                 <li>Tuples</li>
#                 <li>Dictionaries</li>
#             </ul>
#         <b><li><a href="./pc_08.ipynb">Functions</a></li></b>
#             <ul>
#                 <li>Why functions</li>
#                 <li>Defining functions</li>
#                 <li>Parameters</li>
#                 <li>Return values</li>
#             </ul>
#         <b><li><a href="./pc_09.ipynb">Modules and Libraries</a></li></b>
#             <ul>
#                 <li>Importing modules</li>
#                 <li>Using built-in modules</li>
#             </ul>
#         <b><li><a href="./pc_10.ipynb">Basic File Handling</a></li></b>
#             <ul>
#                 <li>Reading</li>
#                 <li>Writing</li>
#             </ul>
#     </ol>
# </div>
