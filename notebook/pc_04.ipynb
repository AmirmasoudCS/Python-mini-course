# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #f3d9ff, #f8cdda);
#     padding: 40px;
#     border-radius: 12px;
#     text-align: center;
# ">
#     <h1>Python Fundamentals</h1>
#     <h2>Session 04 - Operators</h2>
#     <hr style="width: 60%; margin: 20px auto;">
#     <h3>Amirmasoud Mohammadian</h3>
#     <a href="https://github.com/AmirmasoudCS/Python-mini-course"
#        style="display: inline-block; margin-top: 25px; text-decoration:none; color:inherit;" onmouseover="this.style.opacity='0.85'" onmouseout="this.style.opacity='1'">
#         <img src="../GitHub_Lockup_Black.png"
#              style="width: 48px; height: auto; opacity: 0.75; vertical-align:middle; display:inline;">
#              <span style="color:#555; font-size:11px; margin-left:1px; vertical-align:middle"><b>AmirmasoudCS</b></span>
#     </a>
# </div>

# %% [markdown]
# <h2>What are operators</h2>
# <div>
#     <p>Operators are symbols that perform operations on data (variables and values).</p>
# </div>

# %%
x, y = 10, 5
x + y
# Out:
# 15

# %% [markdown]
# <b><ul><li>Arithmetic Operators</li></ul></b>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <title >Assignment Operators Table</title>
#
# <style>
# body{
#     background:#0f0f0f;
#     font-family: Arial, sans-serif;
#     color:white;
# }
#
# .table-container{
#     width:700px;
#     margin:50px auto;
# }
#
# table{
#     width:100%;
#     border-collapse:collapse;
#     overflow:hidden;
#     border-radius:8px;
# }
#
# thead{
#     background:linear-gradient(90deg,#3fbf8f,#4cc3a2);
# }
#
# thead th{
#     padding:14px;
#     text-align:left;
# }
#
# tbody tr{
#     background:#1c1c1c;
# }
#
# tbody tr:nth-child(even){
#     background:#242424;
# }
#
# td{
#     padding:14px;
#     border-bottom:1px solid #333;
# }
# </style>
# </head>
#
# <body>
#
# <div class="table-container">
# <table>
# <thead>
# <tr>
# <th>Operator</th>
# <th>Example</th>
# <th>Equivalent</th>
# </tr>
# </thead>
#
# <tbody>
# <tr>
# <td>=</td>
# <td>x = 5</td>
# <td>—</td>
# </tr>
#
# <tr>
# <td>+=</td>
# <td>x += 3</td>
# <td>x = x + 3</td>
# </tr>
#
# <tr>
# <td>-=</td>
# <td>x -= 3</td>
# <td>x = x - 3</td>
# </tr>
#
# <tr>
# <td>*=</td>
# <td>x *= 3</td>
# <td>x = x * 3</td>
# </tr>
#
# <tr>
# <td>/=</td>
# <td>x /= 3</td>
# <td>x = x / 3</td>
# </tr>
#
# <tr>
# <td>//=</td>
# <td>x //= 3</td>
# <td>x = x // 3</td>
# </tr>
#
# <tr>
# <td>%=</td>
# <td>x %= 3</td>
# <td>x = x % 3</td>
# </tr>
#
# <tr>
# <td>**=</td>
# <td>x **= 2</td>
# <td>x = x ** 2</td>
# </tr>
#
# </tbody>
# </table>
# </div>
#
# </body>
# </html>

# %% [markdown]
# <b><ul><li>Comparison Operators</li></ul></b>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <title>Comparison Operators Table</title>
#
# <style>
# body{
#     background:#0f0f0f;
#     font-family: Arial, sans-serif;
#     color:white;
# }
#
# .table-container{
#     width:750px;
#     margin:50px auto;
# }
#
# table{
#     width:100%;
#     border-collapse:collapse;
#     overflow:hidden;
#     border-radius:8px;
# }
#
# thead{
#     background:linear-gradient(90deg,#3fbf8f,#4cc3a2);
# }
#
# thead th{
#     padding:14px;
#     text-align:left;
# }
#
# tbody tr{
#     background:#1c1c1c;
# }
#
# tbody tr:nth-child(even){
#     background:#242424;
# }
#
# td{
#     padding:14px;
#     border-bottom:1px solid #333;
# }
#
# </style>
# </head>
#
# <body>
#
# <div class="table-container">
# <table>
#
# <thead>
# <tr>
#     <th>Operator</th>
#     <th>Meaning</th>
#     <th>Example</th>
#     <th>Result</th>
# </tr>
# </thead>
#
# <tbody>
# <tr>
#     <td>==</td>
#     <td>Equal to</td>
#     <td>5 == 5</td>
#     <td>True</td>
# </tr>
#
# <tr>
#     <td>!=</td>
#     <td>Not equal to</td>
#     <td>5 != 3</td>
#     <td>True</td>
# </tr>
#
# <tr>
#     <td>&gt;</td>
#     <td>Greater than</td>
#     <td>5 &gt; 2</td>
#     <td>True</td>
# </tr>
#
# <tr>
#     <td>&lt;</td>
#     <td>Less than</td>
#     <td>5 &lt; 2</td>
#     <td>False</td>
# </tr>
#
# <tr>
#     <td>&gt;=</td>
#     <td>Greater or equal</td>
#     <td>5 &gt;= 5</td>
#     <td>True</td>
# </tr>
#
# <tr>
#     <td>&lt;=</td>
#     <td>Less or equal</td>
#     <td>5 &lt;= 5</td>
#     <td>True</td>
# </tr>
#
# </tbody>
#
# </table>
# </div>
#
# </body>
# </html>

# %% [markdown]
# <b><ul><li>Logical Operators</li></ul></b>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <title>Logical Operators Table</title>
#
# <style>
# body {
#     background: #0f0f0f;
#     font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#     color: white;
#     display: flex;
#     justify-content: center;
#     padding-top: 50px;
# }
#
# .table-container {
#     width: 800px;
# }
#
# table {
#     width: 100%;
#     border-collapse: collapse;
#     overflow: hidden;
#     border-radius: 12px; /* Smooth rounded corners */
#     box-shadow: 0 10px 30px rgba(0,0,0,0.5);
# }
#
# thead {
#     background: linear-gradient(90deg, #3fbf8f, #4cc3a2);
# }
#
# thead th {
#     padding: 18px;
#     text-align: center; /* Centered as per image */
#     font-size: 1.1rem;
#     font-weight: 600;
#     letter-spacing: 0.5px;
# }
#
# tbody tr {
#     background: #1c1c1c;
#     transition: background 0.3s;
# }
#
# tbody tr:nth-child(even) {
#     background: #242424;
# }
#
# tbody tr:hover {
#     background: #2a2a2a; /* Subtle hover effect */
# }
#
# td {
#     padding: 20px;
#     text-align: center; /* Centered as per image */
#     border-bottom: 1px solid #333;
#     font-size: 1rem;
# }
#
# /* Specific styling for the operator text to make it stand out */
# td:first-child {
#     font-family: 'Courier New', Courier, monospace;
#     font-weight: bold;
#     color: #4cc3a2;
# }
# </style>
# </head>
#
# <body>
#
# <div class="table-container">
# <table>
#
# <thead>
# <tr>
#     <th>Operator</th>
#     <th>Meaning</th>
# </tr>
# </thead>
#
# <tbody>
# <tr>
#     <td>and</td>
#     <td>True if both are True</td>
# </tr>
#
# <tr>
#     <td>or</td>
#     <td>True if one is True</td>
# </tr>
#
# <tr>
#     <td>not</td>
#     <td>Reverses True/False</td>
# </tr>
#
# </tbody>
#
# </table>
# </div>
#
# </body>
# </html>

# %% [markdown]
# <h2>Operator Precedence</h2>

# %% [markdown]
# <div>
#     <ol>
#         <li> ()</li>
#         <li> ** </li>
#         <li> *, /, //, %</li>
#         <li> +, - </li>
#         <li> Comparisons </li>
#         <li> Logical</li>
#     </ol>
# </div>

# %%
is_logged_in = True
age_qualification = False
if is_logged_in and age_qualification:
    print("Welcome!")
else:
    print("Don't Welcome!?")
# Out:
# Don't Welcome!?
