# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #f3d9ff, #f8cdda);
#     padding: 40px;
#     border-radius: 12px;
#     text-align: center;
# ">
#     <h1>Python Fundamentals</h1>
#     <h2>Session 02 - Variables and Data Types</h2>
#     <hr style="width: 60%; margin: 20px auto;">
#     <h3>Amirmasoud Mohammadian</h3>
#     <a href="https://github.com/AmirmasoudCS/Python-mini-course"
#        style="display: inline-block; margin-top: 25px; text-decoration:none; color:inherit;" onmouseover="this.style.opacity='0.85'" onmouseout="this.style.opacity='1'">
#         <img src="../GitHub_Lockup_Black.png"
#              style="width: 48px; height: auto; opacity: 0.75; vertical-align:middle; display:inline;">
#              <span style="color:#555; font-size:11px; margin-left:1px; vertical-align:middle"><b>AmirmasoudCS</b></span>
#     </a>
# </div>

# %% [markdown]
# <h1>Variables</h1>
# <div>
#     <ul>
#         <li>What is a variable?</li>
#         <li>How to assign a value?</li>
#         <li>How to print a variable</li>
#     </ul>
# </div>

# %%
name = "Amir"
age = 20

# %%
print(name)
# Out:
# Amir

# %%
print(age)
# Out:
# 20

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
isinstance(name, str)
# Out:
# True

# %%
isinstance(name, int)
# Out:
# False

# %%
isinstance(name, (int,str))
# Out:
# True

# %% [markdown]
# <hr>
# <h1>Python is Dynamically Typed</h1>

# %% [markdown]
# <div><p><b>Python</b> automatically detects data type.</p></div>

# %%
x = 10
print(type(x))
print(x)
# Out:
# <class 'int'>
# 10

# %%
x = "Ten"
print(type(x))
print(x)
# Out:
# <class 'str'>
# Ten

# %% [markdown]
# <hr>
# <h1>Core Data Types</h1>

# %% [markdown]
# <h2>Integer (int)</h2>
# <div>
# <ul>
#     <li>Whole Numbers</li>
#     <li>Positive / Negative</li>
#     <li>No decimal</li>
# </ul>
# </div>

# %%
a = 10
b = -5

# %% [markdown]
# <h2>Float</h2>
# <div>
#     <ul>
#         <li>Decimal Numbers</li>
#         <li>Scientific Notation</li>
#     </ul>
# </div>

# %%
price = 9.99
x = 3.5
y = 2e3 
z = 5.0

# %%
type(z)
# Out:
# float

# %%
y
# Out:
# 2000.0

# %%
type(y)
# Out:
# float

# %% [markdown]
# <h2>String</h2>

# %%
name = "Masoud" 
country = 'Germany'

# %%
multi_line_text = """This
            is
                        a
                multi
            line
    text
                                    """

# %%
multi_line_text
# Out:
# 'This\n            is\n                        a\n                multi\n            line\n    text\n                                    '

# %%
name = "Python"

# %%
name[0]
# Out:
# 'P'

# %%
name[5]
# Out:
# 'n'

# %%
name[-1]
# Out:
# 'n'

# %%
name[-6]
# Out:
# 'P'

# %%
len(name)
# Out:
# 6

# %% [markdown]
# <h2>Boolean</h2>

# %% [markdown]
# <div>
#     Only two values
#     <ul>
#         <li>True</li>
#         <li>False</li>
#     </ul>
# </div>

# %%
is_student = True
type(is_student)
# Out:
# bool

# %%
print(10 > 5)
# Out:
# True

# %% [markdown]
# <h2>Type Conversion</h2>
# <div><span>Sometimes data must change type</span></div>

# %%
age = "20"
age + "1"
# Out:
# '201'

# %%
age = int(age)
age + 1
# Out:
# 21

# %%
age = age + 1

# %%
age
# Out:
# 21

# %%
age += 1

# %%
age
# Out:
# 23

# %% [markdown]
# <ul>
#     <li>int()</li>
#     <li>float()</li>
#     <li>str()</li>
#     <li>bool()</li>
# </ul>

# %% [markdown]
# <h2>Multiple Assignments</h2>

# %%
a = 5
b = 10
a + b
# Out:
# 15

# %%
x, y = 5, 10
x + y
# Out:
# 15

# %%
a, b, c, d = 1, 2, 3, 4
a + b + c + d
# Out:
# 10

# %% [markdown]
# <h2>Swap</h2>

# %%
a = 2
b = 7
a, b
# Out:
# (2, 7)

# %% [markdown]
# <h3>Method 1</h3>

# %%
hold = a
a = b
b = hold
a, b
# Out:
# (7, 2)

# %% [markdown]
# <h3>Method 2</h3>

# %%
x, y = 2, 7
x, y
# Out:
# (2, 7)

# %%
x, y = y, x
x, y
# Out:
# (7, 2)

# %% [markdown]
# <h2>Constants</h2>

# %% [markdown]
# <div>
#     Python has no real constant keyword.<br>We write constants in <b>UPPERCASE</b>.
# </div>

# %%
PI = 3.14159
MAX_WEBSITE_USERS = 1000
MIN_VALUE = 50

# %%
PI
# Out:
# 3.14159

# %%
PI = "lkng[eiwnh"

# %%
PI
# Out:
# 'lkng[eiwnh'
